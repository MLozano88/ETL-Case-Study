# %%
import pandas as pd

# %%
file = 'Resources/netflix_titles.csv'

# %%
netflix_df=pd.read_csv(file, encoding="ISO-8859-1")

# %%
netflix_df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...         Brazil
# 1  DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
netflix_df=netflix_df.drop(['show_id','cast','date_added','rating','duration','listed_in','description'], axis=1)

# %%
netflix_df = netflix_df.rename(columns={"type":"Type","title":"Movie","director":"Director","country":"Country","release_year":"Year"})
netflix_df.head()
# Out:
#       Type  Movie           Director        Country  Year
# 0  TV Show     3%                NaN         Brazil  2020
# 1    Movie   7:19  Jorge Michel Grau         Mexico  2016
# 2    Movie  23:59       Gilbert Chan      Singapore  2011
# 3    Movie      9        Shane Acker  United States  2009
# 4    Movie     21     Robert Luketic  United States  2008

# %%
index_names=netflix_df[netflix_df["Type"]=="TV Show"].index
netflix_df.drop(index_names,inplace=True)

# %%
netflix_df.sample(20)
# Out:
#        Type                                             Movie  \
# 1363  Movie                               Christmas Crossfire
# 5917  Movie                                  Surat Dari Praha
# 737   Movie                          Barbie in A Mermaid Tale
# 1909  Movie                                   East Side Sushi
# 4447  Movie                                      Neseli Hayat
# 5847  Movie                                     Strike a Pose
# 7312  Movie                                               Una
# 2379  Movie                                     Gerald's Game
# 1919  Movie                                 Eddie Murphy: Raw
# 2948  Movie                       Iliza Shlesinger: War Paint
# 5048  Movie                                    Raat Akeli Hai
# 3937  Movie                                             Maria
# 2336  Movie                           Gagarin: First in Space
# 362   Movie                                          AK vs AK
# ...

# %%
newnetflix_df=netflix_df.drop['Type']
netnetflix_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-53bb65cbd1e1> in <module>
# ----> 1 newnetflix_df=netflix_df.drop['Type']
#       2 netnetflix_df.head()
#
# TypeError: 'method' object is not subscriptable

# %%
netflix_df.head())
# Out:
#   File "<ipython-input-18-44437995d582>", line 1
#     netflix_df.head())
#                      ^
# SyntaxError: unmatched ')'
